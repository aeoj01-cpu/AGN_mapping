# %%
import os
os.chdir(r"C:\Users\Annie.LAPTOP-NJ5KV9M1\AGN_mapping")

# %%
pip install astropy scipy matplotlib numpy h5py tqdm numba pint-pulsar emcee corner statsmodels pyfftw tbb
# Out:
# Requirement already satisfied: astropy in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (6.1.0)
# Requirement already satisfied: scipy in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (1.15.2)
# Requirement already satisfied: matplotlib in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (3.10.8)
# Requirement already satisfied: numpy in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (1.23.5)
# Requirement already satisfied: h5py in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (3.15.1)
# Requirement already satisfied: tqdm in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (4.67.3)
# Requirement already satisfied: numba in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (0.56.4)
# Requirement already satisfied: pint-pulsar in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (1.1.4)
# Requirement already satisfied: emcee in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (3.1.6)
# Requirement already satisfied: corner in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (2.2.3)
# Requirement already satisfied: statsmodels in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (0.14.6)
# Requirement already satisfied: pyfftw in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (0.15.1)
# Requirement already satisfied: tbb in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (2022.3.1)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from astropy) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2024.4.29.0.28.48 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from astropy) (0.2026.2.23.0.48.33)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from astropy) (6.0.3)
# Requirement already satisfied: packaging>=19.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from astropy) (26.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from tqdm) (0.4.6)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from numba) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from numba) (80.10.2)
# Requirement already satisfied: jplephem>=2.6 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pint-pulsar) (2.24)
# Requirement already satisfied: uncertainties in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pint-pulsar) (3.2.3)
# Requirement already satisfied: loguru in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pint-pulsar) (0.7.3)
# Requirement already satisfied: nestle>=0.2.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pint-pulsar) (0.2.1)
# Requirement already satisfied: numdifftools in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pint-pulsar) (0.9.42)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: tcmlib==1.* in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from tbb) (1.4.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: win32-setctime>=1.0.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from loguru->pint-pulsar) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pytest pytest-astropy jinja2 docutils sphinx-astropy nbsphinx pandoc ipython jupyter notebook towncrier tox black
# Out:
# Requirement already satisfied: pytest in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (9.0.2)
# Requirement already satisfied: pytest-astropy in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (0.11.0)
# Requirement already satisfied: jinja2 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (3.1.6)
# Requirement already satisfied: docutils in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (0.22.4)
# Requirement already satisfied: sphinx-astropy in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (1.10)
# Requirement already satisfied: nbsphinx in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (0.9.8)
# Requirement already satisfied: pandoc in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (2.4)
# Requirement already satisfied: ipython in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (8.30.0)
# Requirement already satisfied: jupyter in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (1.1.1)
# Requirement already satisfied: notebook in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (7.5.3)
# Requirement already satisfied: towncrier in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (25.8.0)
# Requirement already satisfied: tox in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (4.45.0)
# Requirement already satisfied: black in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (26.1.0)
# Requirement already satisfied: colorama>=0.4 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest) (0.4.6)
# Requirement already satisfied: exceptiongroup>=1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest) (1.2.0)
# Requirement already satisfied: iniconfig>=1.0.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest) (2.3.0)
# Requirement already satisfied: packaging>=22 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest) (26.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest) (2.19.2)
# Requirement already satisfied: tomli>=1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest) (2.4.0)
# Requirement already satisfied: pytest-doctestplus>=1.0.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest-astropy) (1.7.1)
# Requirement already satisfied: pytest-remotedata>=0.4.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest-astropy) (0.4.1)
# Requirement already satisfied: pytest-astropy-header>=0.2.2 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest-astropy) (0.2.2)
# Requirement already satisfied: pytest-arraydiff>=0.5 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest-astropy) (0.6.1)
# Requirement already satisfied: pytest-filter-subpackage>=0.1.2 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest-astropy) (0.2.0)
# Requirement already satisfied: pytest-cov>=2.3.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest-astropy) (7.0.0)
# Requirement already satisfied: pytest-mock>=2.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest-astropy) (3.15.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest-astropy) (25.4.0)
# Requirement already satisfied: hypothesis>=5.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest-astropy) (6.151.9)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jinja2) (3.0.3)
# Requirement already satisfied: sphinx>=4.0.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx-astropy) (9.0.4)
# Requirement already satisfied: astropy-sphinx-theme in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx-astropy) (2.0)
# Requirement already satisfied: numpydoc in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx-astropy) (1.10.0)
# Requirement already satisfied: sphinx-automodapi in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx-astropy) (0.22.0)
# Requirement already satisfied: sphinx-gallery in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx-astropy) (0.20.0)
# Requirement already satisfied: sphinxcontrib-jquery in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx-astropy) (4.1)
# Requirement already satisfied: pillow in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx-astropy) (11.1.0)
# Requirement already satisfied: nbconvert!=5.4,>=5.3 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from nbsphinx) (7.17.0)
# Requirement already satisfied: nbformat in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from nbsphinx) (5.10.4)
# Requirement already satisfied: traitlets>=5 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from nbsphinx) (5.14.3)
# Requirement already satisfied: plumbum in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pandoc) (1.10.0)
# Requirement already satisfied: ply in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pandoc) (3.11)
# Requirement already satisfied: decorator in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from ipython) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from ipython) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from ipython) (0.2.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from ipython) (3.0.52)
# Requirement already satisfied: stack-data in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from ipython) (0.6.3)
# Requirement already satisfied: typing-extensions>=4.6 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from ipython) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython) (0.6.0)
# Requirement already satisfied: jupyter-console in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: ipykernel in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter) (7.2.0)
# Requirement already satisfied: ipywidgets in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter) (8.1.8)
# Requirement already satisfied: jupyterlab in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter) (4.5.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from notebook) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from notebook) (2.28.0)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from notebook) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from notebook) (6.5.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.12.1)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.5.4)
# Requirement already satisfied: overrides>=5.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.24.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (3.0.3)
# Requirement already satisfied: pyzmq>=24 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.9.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyterlab->jupyter) (2.2.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyterlab->jupyter) (80.10.2)
# Requirement already satisfied: certifi in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: babel>=2.10 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (0.13.0)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (4.26.0)
# Requirement already satisfied: requests>=2.31 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyterlab-server<3,>=2.28.0->notebook) (2.32.5)
# Requirement already satisfied: click in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from towncrier) (8.3.1)
# Requirement already satisfied: cachetools>=7.0.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from tox) (7.0.1)
# Requirement already satisfied: chardet>=6.0.0.post1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from tox) (6.0.0.post1)
# Requirement already satisfied: filelock>=3.24.3 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from tox) (3.24.3)
# Requirement already satisfied: platformdirs>=4.9.2 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from tox) (4.9.2)
# Requirement already satisfied: pyproject-api>=1.10 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from tox) (1.10.0)
# Requirement already satisfied: virtualenv>=20.38 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from tox) (20.39.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from black) (1.1.0)
# Requirement already satisfied: pathspec>=1.0.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from black) (1.0.4)
# Requirement already satisfied: pytokens>=0.3.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from black) (0.4.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (25.1.0)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from hypothesis>=5.1->pytest-astropy) (2.4.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from ipykernel->jupyter) (1.8.16)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from ipykernel->jupyter) (7.0.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jedi>=0.16->ipython) (0.8.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->notebook) (0.30.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (2.9.0.post0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (6.0.3)
# Requirement already satisfied: rfc3339-validator in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from nbconvert!=5.4,>=5.3->nbsphinx) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx) (6.3.0)
# Requirement already satisfied: defusedxml in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from nbconvert!=5.4,>=5.3->nbsphinx) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from nbconvert!=5.4,>=5.3->nbsphinx) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from nbconvert!=5.4,>=5.3->nbsphinx) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from nbconvert!=5.4,>=5.3->nbsphinx) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from nbconvert!=5.4,>=5.3->nbsphinx) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from bleach[css]!=5.0.0->nbconvert!=5.4,>=5.3->nbsphinx) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from nbformat->nbsphinx) (2.21.2)
# Requirement already satisfied: numpy in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from pytest-arraydiff>=0.5->pytest-astropy) (1.23.5)
# Requirement already satisfied: coverage>=7.10.6 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from coverage[toml]>=7.10.6->pytest-cov>=2.3.1->pytest-astropy) (7.13.4)
# Requirement already satisfied: six>=1.5 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.28.0->notebook) (2.6.3)
# Requirement already satisfied: lark>=1.2.2 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.3.1)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx>=4.0.0->sphinx-astropy) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx>=4.0.0->sphinx-astropy) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx>=4.0.0->sphinx-astropy) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx>=4.0.0->sphinx-astropy) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx>=4.0.0->sphinx-astropy) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx>=4.0.0->sphinx-astropy) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx>=4.0.0->sphinx-astropy) (3.0.1)
# Requirement already satisfied: alabaster>=0.7.14 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx>=4.0.0->sphinx-astropy) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx>=4.0.0->sphinx-astropy) (1.4.1)
# Requirement already satisfied: roman-numerals>=1.0.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from sphinx>=4.0.0->sphinx-astropy) (4.1.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from virtualenv>=20.38->tox) (0.4.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from beautifulsoup4->nbconvert!=5.4,>=5.3->nbsphinx) (2.8.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from ipywidgets->jupyter) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from ipywidgets->jupyter) (3.0.16)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (1.4.0)
# Requirement already satisfied: tzdata in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook) (2025.3)
# Requirement already satisfied: pywin32 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from plumbum->pandoc) (311)
# Requirement already satisfied: executing>=1.2.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from stack-data->ipython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from stack-data->ipython) (3.0.1)
# Requirement already satisfied: pure_eval in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from stack-data->ipython) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install stingray PyROA emcee tabulate corner astropy
# Out:
# Requirement already satisfied: stingray in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (2.2.10)
# Requirement already satisfied: PyROA in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (3.2.2)
# Requirement already satisfied: emcee in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (3.1.6)
# Requirement already satisfied: tabulate in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (0.9.0)
# Requirement already satisfied: corner in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (2.2.3)
# Requirement already satisfied: astropy in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (6.1.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from stingray) (1.23.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from stingray) (1.15.2)
# Requirement already satisfied: matplotlib!=3.4.00,>=3.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from stingray) (3.10.8)
# Requirement already satisfied: pyerfa>=2.0.1.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from astropy) (2.0.1.5)
# Requirement already satisfied: astropy-iers-data>=0.2024.4.29.0.28.48 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from astropy) (0.2026.2.23.0.48.33)
# Requirement already satisfied: PyYAML>=3.13 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from astropy) (6.0.3)
# Requirement already satisfied: packaging>=19.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from astropy) (26.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib!=3.4.00,>=3.0->stingray) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib!=3.4.00,>=3.0->stingray) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib!=3.4.00,>=3.0->stingray) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib!=3.4.00,>=3.0->stingray) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib!=3.4.00,>=3.0->stingray) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib!=3.4.00,>=3.0->stingray) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from matplotlib!=3.4.00,>=3.0->stingray) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\annie.laptop-nj5kv9m1\miniconda3\envs\agn\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.4.00,>=3.0->stingray) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import shutil

# Replace '/path/to/work_directory' with your actual work directory

src = r'C:\Users\Annie.LAPTOP-NJ5KV9M1\AGN_mapping\CPython\PYCCF.py'
dst = r'PYCCF.py'
dst2 = r'xcorspc.pyx'

shutil.copy(src, dst)
shutil.copy(src, dst2)
# Out:
# 'xcorspc.pyx'

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Annie.LAPTOP-NJ5KV9M1\AGN_mapping

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import argparse
import random

from scipy import stats
import scipy.integrate as integrate

from stingray import Lightcurve, Crossspectrum, AveragedCrossspectrum

import PYCCF as myccf
import PyROA
import psi

import importlib
importlib.reload(psi)
# Out:
# <module 'psi' from 'C:\\Users\\Annie.LAPTOP-NJ5KV9M1\\AGN_mapping\\psi.py'>

# %%
import scipy
print(scipy.__version__)
print(scipy.__file__)
# Out:
# 1.15.2
# c:\Users\Annie.LAPTOP-NJ5KV9M1\miniconda3\envs\agn\lib\site-packages\scipy\__init__.py

# %%
#import AGN light curve
directory_path = r'C:\Users\Annie.LAPTOP-NJ5KV9M1\AGN_mapping\data'
file_path = os.path.join(directory_path, 'lc30mins.dat')

column_index1 = 0  
column_index2 = 1

with open(file_path, 'r') as file:
    # Read all lines
    lines = file.readlines()
    data_lines = lines[1:]
    
   # Extract the desired columns from each line and convert to float
    column1_data = [float(line.split()[column_index1]) for line in data_lines]
    column2_data = [float(line.split()[column_index2]) for line in data_lines]

time = np.array(column1_data)/(24*3600)
flux = np.array(column2_data)

# %% [markdown]
# ## Generate Light curves and Response functions

# %% [markdown]
# creating a code which creates a combined lightcurve taking inputs of BLR and accretion disk using BLR fraction

# %% [markdown]
# # Mixed Disk and BLR Reverberation Model
#
# ## Aim
#
# To investigate how varying the relative contribution of the Broad Line Region (BLR) and accretion disk affects the observed lag-frequency spectrum in UV/optical reverberation mapping.
#
# ## Physical Model
#
# The observed emission is assumed to arise from two reprocessing components:
#
# - An accretion disk transfer function calculated using `pytfb_sub`.
# - A BLR transfer function approximated as a log-normal distribution.
#
# The total transfer function is
#
# Ψ(t) = (1-f_BLR)Ψ_disk(t) + f_BLRΨ_BLR(t)
#
# where f_BLR is the fractional BLR contribution.
#
# The driving continuum is convolved with this combined response function to produce the observed light curve.
#
# ## Goals
#
# - Examine how BLR fraction modifies the lag-frequency spectrum.
# - Compare simulations with NGC4151 observations.
# - Determine whether Fourier lags can distinguish disk and BLR emission.

# %%
#########################################
##Set Interpolation settings, user-specified
#########################################
lag_range = [-100, 100]  #Time lag range to consider in the CCF (days). Must be small enough that there is some overlap between light curves at that shift (i.e., if the light curves span 80 days, these values must be less than 80 days)
interp = 0.2 #Interpolation time step (days). Must be less than the average cadence of the observations, but too small will introduce noise.
nsim = 10  #Number of Monte Carlo iterations for calculation of uncertainties
mcmode = 0  #Do both FR/RSS sampling (1 = RSS only, 2 = FR only) 
sigmode = 0.2  #Choose the threshold for considering a measurement "significant". sigmode = 0.2 will consider all CCFs with r_max <= 0.2 as "failed". See code for different sigmodes.
#########################################
##Set freq-lag settings, user-specified
#########################################
cs_binning = 100 #averaged cross spectrum binning 
error_in_flux = 0.01 #define percentage error in flux 
SN = 100 #sound to noise ratio 
samplng_rate = 1 #how many samples are taken per day 
sampling_loss = 0.2 # the amount of data lost due to sampling issues
final_length = 350 #length of final array in days 
dt = 1800 #each interval in seconds 
S = 1.0 #SD of BLR function
M = np.log(13.9) # Mean of BLR function
BLR_fraction = 0.5 # BLR fraction

exposure = len(time) #length of full array 
seconds_day = 86400
original_length = exposure/(seconds_day/dt)

times = (np.linspace(-exposure, exposure+1, num = exposure*2)*dt)/(24*3600) # converted to days

#define disk function
def disk(times,wavelength,A1):
    bhmass = 10**7.7       # Msol
    mdot = 0.5         # Msol/yr
    inc = 45           # inclination, degrees
    combi_psi = psi.pytfb_sub(times,1e8,mdot,wavelength,inc,norm=1)
    combi_psi[np.isnan(combi_psi)]=0
    # normalise 
    normi = np.trapz(combi_psi,x=times)
    return A1*(combi_psi/normi)

# Define BLR function
def BLR(times,A2):

    BLR_array = A2/(S*times*np.sqrt(2*np.pi))*np.exp(-(np.log(times)-M)**2/(2*(S**2)))
    BLR_array[np.isnan(BLR_array)]=0
    return  BLR_array

BLR_array_1 = BLR(times, BLR_fraction)
combi_psi_1 = disk(times, 4770, (1 - BLR_fraction))

signal_BLR_Disk = BLR_array_1 + combi_psi_1

### Perform convolution
signal4_BLR = np.convolve(flux, signal_BLR_Disk, mode='full')
signal_BLR = np.convolve(flux, BLR(times, 1), mode='full')
signal_DISK = np.convolve(flux, disk(times, 4770, 1), mode='full')

start_index = int((len(signal4_BLR) - len(flux)) / 2)
end_index = start_index + len(flux)
signal4_BLR = signal4_BLR[start_index:end_index]

start_index1 = int((len(signal_BLR) - len(flux)) / 2)
end_index1 = start_index1 + len(flux)
signal_BLR = signal_BLR[start_index1:end_index1]

start_index2 = int((len(signal_DISK) - len(flux)) / 2)
end_index2 = start_index2 + len(flux)
signal_DISK = signal_DISK[start_index2:end_index2]

#take a smaple each day 
interval = (original_length-final_length)/2
start = int(seconds_day/dt*interval)
end = int(seconds_day/dt*(original_length-interval))

signal_combined = signal4_BLR[start:end]
signal_BLR = signal_BLR[start:end]
signal_DISK = signal_DISK[start:end]
flux = flux[start:end]
time = time[start:end]

lc_BLR = Lightcurve(time,signal_BLR )
lc_full = Lightcurve(time,signal_combined )
lc_disk = Lightcurve(time,signal_DISK )
lc = Lightcurve(time,flux)
# Out:
# C:\Users\Annie.LAPTOP-NJ5KV9M1\AppData\Local\Temp\ipykernel_18748\1919663901.py:43: RuntimeWarning: invalid value encountered in log
#   BLR_array = A2/(S*times*np.sqrt(2*np.pi))*np.exp(-(np.log(times)-M)**2/(2*(S**2)))
# c:\Users\Annie.LAPTOP-NJ5KV9M1\miniconda3\envs\agn\lib\site-packages\stingray\lightcurve.py:329: UserWarning: On Windows, the size of an integer is 32 bits. To avoid integer overflow, I'm converting the input array to float
#   warnings.warn(

# %%
new_times = []
new_BLR = []
new_disk = []
new_full = []
new_flux = []


#sample randomly
for i in range(final_length):
    
    random_number = random.randint(0, seconds_day/dt)
    index = int(i*seconds_day/dt) + random_number
    
    new_times.append(time[index])
    new_flux.append(flux[index])
    new_BLR.append(signal_BLR[index])
    new_disk.append(signal_DISK[index])
    new_full.append(signal_combined[index])


lost_data = int(len(new_flux)*sampling_loss)  

#remove lost data
for i in range(lost_data):
    
    random_number = random.randint(0,len(new_times)-1)
    new_flux.pop(random_number)
    new_times.pop(random_number)
    new_BLR.pop(random_number)
    new_disk.pop(random_number)
    new_full.pop(random_number)

#create lightcurves
lc_BLR = Lightcurve(new_times,new_BLR )
lc = Lightcurve(new_times,new_flux)
lc_full = Lightcurve(new_times,new_full )
lc_disk = Lightcurve(new_times,new_disk )
# Out:
# c:\Users\Annie.LAPTOP-NJ5KV9M1\miniconda3\envs\agn\lib\site-packages\stingray\utils.py:487: UserWarning: SIMON says: Bin sizes in input time array aren't equal throughout! This could cause problems with Fourier transforms. Please make the input time evenly sampled.Only use with LombScargleCrossspectrum, LombScarglePowerspectrum and QPO using GPResult
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)

# %%
#getting mean 
mean_lc_full = np.mean(lc_full.counts)
mean_lc_disk = np.mean(lc_disk.counts)
mean_lc_BLR = np.mean(lc_BLR.counts)
mean_lc = np.mean(lc.counts)

#getting standard deviation
sd_lc_full = np.std(lc_full.counts)
sd_lc_disk = np.std(lc_disk.counts)
sd_lc_BLR = np.std(lc_BLR.counts)
sd_lc = np.std(lc.counts)

#normalising
lc_full_N = (lc_full.counts-mean_lc_full)/sd_lc_full
lc_disk_N = (lc_disk.counts-mean_lc_disk)/sd_lc_disk
lc_BLR_N = (lc_BLR.counts-mean_lc_BLR)/sd_lc_BLR
lc_N = (lc.counts-mean_lc)/sd_lc

# and adding noise
lc_full_N = np.random.normal(lc_full_N,abs(lc_full_N/SN))
lc_disk_N = np.random.normal(lc_disk_N,abs(lc_disk_N/SN))
lc_BLR_N = np.random.normal(lc_BLR_N,abs(lc_BLR_N/SN))
lc_N = np.random.normal(lc_N,abs(lc_N/SN))

#create normalised lightcurves
lc_full_N = Lightcurve(lc_BLR.time,lc_full_N)
lc_disk_N = Lightcurve(lc_disk.time,lc_disk_N)
lc_BLR_N = Lightcurve(lc_BLR.time,lc_BLR_N)
lc_N = Lightcurve(lc.time,lc_N)

#create errors in flux 
lc_N.counts_err = abs(lc_N.counts*error_in_flux)
lc_BLR_N.counts_err = abs(lc_BLR_N.counts*error_in_flux)
lc_disk_N.counts_err = abs(lc_disk_N.counts*error_in_flux)
lc_full_N.counts_err = abs(lc_full_N.counts*error_in_flux)

# %%
#perform interpolation using PYROA
(lc_P_times,lc_P_counts,lc_P_err) = PyROA.RunningOptimalAverage(lc_N.time,lc_N.counts,lc_N.counts_err,1)
(lc_BLR_P_times,lc_BLR_P_counts,lc_BLR_P_err) = PyROA.RunningOptimalAverage(lc_BLR_N.time,lc_BLR_N.counts,lc_BLR_N.counts_err,1)
(lc_full_P_times,lc_full_P_counts,lc_full_P_err) = PyROA.RunningOptimalAverage(lc_full_N.time,lc_full_N.counts,lc_full_N.counts_err,1)
(lc_disk_P_times,lc_disk_P_counts,lc_disk_P_err) = PyROA.RunningOptimalAverage(lc_disk_N.time,lc_disk_N.counts,lc_disk_N.counts_err,1)

#create the interpolated Lightcurves
lcp = Lightcurve(lc_P_times,lc_P_counts,err = lc_P_err)
lcBLRp = Lightcurve(lc_BLR_P_times,lc_BLR_P_counts,err = lc_BLR_P_err)
lcfullp = Lightcurve(lc_full_P_times,lc_full_P_counts,err = lc_full_P_err)
lcdiskp = Lightcurve(lc_disk_P_times,lc_disk_P_counts,err = lc_disk_P_err)
# Out:
# c:\Users\Annie.LAPTOP-NJ5KV9M1\miniconda3\envs\agn\lib\site-packages\stingray\lightcurve.py:329: UserWarning: On Windows, the size of an integer is 32 bits. To avoid integer overflow, I'm converting the input array to float
#   warnings.warn(

# %%
# Create subplots with 2 rows and 2 columns
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(8, 6))

axes[0].plot(lcp.time, lcp.counts, lw=2, color='red')
axes[0].plot( lcBLRp.time,lcBLRp.counts, lw=2, color='green',label = 'BLR')
axes[0].plot( lcfullp.time,lcfullp.counts, lw=2, color='blue',label = 'mixture model')
axes[0].plot( lcdiskp.time,lcdiskp.counts, lw=2, color='orange',label = 'disk')
axes[0].set_xlabel("Time (days)",fontsize=12 )
axes[0].set_ylabel("Flux (erg/s/cm²)",fontsize=15)
axes[0].tick_params(axis='x', labelsize=8)
axes[0].tick_params(axis='y', labelsize=8)
axes[0].legend()

axes[1].plot(times, BLR_array_1, lw=2, color='green',label = 'BLR')
axes[1].plot(times, combi_psi_1, lw=2, color='orange',label = 'disk')
axes[1].plot(times, signal_BLR_Disk, lw=2, color='blue',label = 'mixture model')
axes[1].set_xlabel("Time (days)",fontsize=15 )
axes[1].set_ylabel(r"reponse function ($\psi$)",fontsize=15)
axes[1].set_xlim(0,50)
axes[1].tick_params(axis='x', labelsize=8)
axes[1].tick_params(axis='y', labelsize=8)
axes[1].legend()



# Adjust layout to prevent overlap
plt.tight_layout()

# Show or save the figure
plt.show()

# %% [markdown]
# ## Detrend find cross spectrum and frequency resolved lags

# %%
#detrend 

# Define a function to detrend a dataset
def detrend_data(time, counts):
    # Fit a linear model to the data
    m, b = np.polyfit(time, counts, 1)
    
    # Calculate the linear trend
    linear_trend = m * time + b
    
    # Subtract the linear trend from the original data
    detrended_counts = counts - linear_trend
    
    return detrended_counts

# Detrend lcfullp
detrended_counts_full = detrend_data(lcfullp.time, lcfullp.counts)

# Detrend lcdiskp
detrended_counts_disk = detrend_data(lcdiskp.time, lcdiskp.counts)

# Detrend lcBLRp
detrended_counts_BLR = detrend_data(lcBLRp.time, lcBLRp.counts)

# Detrend lcp
detrended_counts_p = detrend_data(lcp.time, lcp.counts)

# %%
#create the interpolated Lightcurves
lcp = Lightcurve(lc_P_times,detrended_counts_p,err = lc_P_err)
lcBLRp = Lightcurve(lc_BLR_P_times,detrended_counts_BLR,err = lc_BLR_P_err)
lcfullp = Lightcurve(lc_full_P_times,detrended_counts_full,err = lc_full_P_err)
lcdiskp = Lightcurve(lc_disk_P_times,detrended_counts_disk,err = lc_disk_P_err)

# %%
#average cross spectrum 
avg_cs_BLR = AveragedCrossspectrum.from_lightcurve(lcBLRp, lcp, cs_binning)
avg_cs_full = AveragedCrossspectrum.from_lightcurve(lcfullp, lcp, cs_binning)
avg_cs_disk = AveragedCrossspectrum.from_lightcurve(lcdiskp, lcp, cs_binning)

#logarithmically rebin 
log_rb_cs_BLR = avg_cs_BLR.rebin_log(f=1.2)
log_rb_cs_full = avg_cs_full.rebin_log(f=1.2)
log_rb_cs_disk = avg_cs_disk.rebin_log(f=1.2)

#define time and phase lags 
freq_lags_BLR, freq_lags_err_BLR = log_rb_cs_BLR.time_lag()
freq_lags_full, freq_lags_err_full = log_rb_cs_full.time_lag()
freq_lags_disk, freq_lags_err_disk = log_rb_cs_disk.time_lag()
# Out:
# 3it [00:00, 180.77it/s]
# c:\Users\Annie.LAPTOP-NJ5KV9M1\miniconda3\envs\agn\lib\site-packages\stingray\fourier.py:1134: UserWarning: n_ave is below 30. Please note that the error bars on the quantities derived from the cross spectrum are only reliable for a large number of averaged powers.
#   warnings.warn(
# c:\Users\Annie.LAPTOP-NJ5KV9M1\miniconda3\envs\agn\lib\site-packages\stingray\fourier.py:1161: RuntimeWarning: invalid value encountered in sqrt
#   dphi = np.sqrt((1 - gsq) / (2 * gsq * n_ave))
# 3it [00:00, 855.34it/s]
# 3it [00:00, 1196.78it/s]
# c:\Users\Annie.LAPTOP-NJ5KV9M1\miniconda3\envs\agn\lib\site-packages\stingray\fourier.py:1134: UserWarning: n_ave is below 30. Please note that the error bars on the quantities derived from the cross spectrum are only reliable for a large number of averaged powers.
#   warnings.warn(
# c:\Users\Annie.LAPTOP-NJ5KV9M1\miniconda3\envs\agn\lib\site-packages\stingray\fourier.py:1161: RuntimeWarning: invalid value encountered in sqrt
#   dphi = np.sqrt((1 - gsq) / (2 * gsq * n_ave))

# %%
print(freq_lags_BLR)
print(freq_lags_full)
print(freq_lags_disk)
# Out:
# [ 1.37910037e+01  8.78941324e+00  5.28313020e+00  3.27373627e+00
#  -9.77849424e-01  1.97440755e-02  3.13877792e-03]
# [ 6.49357375e+00  3.45139728e+00  1.72753763e+00  1.01806084e+00
#  -3.33395195e-03 -2.90778681e-03  3.08095770e-04]
# [ 1.77669295e+00  1.49687848e+00  1.29405709e+00  1.04745382e+00
#   6.38640865e-02 -1.30560878e-03 -1.20925278e-04]

# %% [markdown]
# ## Find mean Lag using response function

# %%
response_function = BLR(times,BLR_fraction)+disk(times, 4770, (1 - BLR_fraction))
BLR_array = BLR(times,1)
Disk_array = disk(times, 4770, 1)
#find mean lag 
mean_lag_full = np.sum(response_function * times) / np.sum(response_function)
mean_lag_BLR = np.sum(BLR_array * times) / np.sum(BLR_array)
mean_lag_Disk = np.sum(Disk_array * times) / np.sum(Disk_array)
# Out:
# C:\Users\Annie.LAPTOP-NJ5KV9M1\AppData\Local\Temp\ipykernel_18748\1919663901.py:43: RuntimeWarning: invalid value encountered in log
#   BLR_array = A2/(S*times*np.sqrt(2*np.pi))*np.exp(-(np.log(times)-M)**2/(2*(S**2)))

# %%
# Plotting
plt.figure(figsize=(6, 4))
plt.hlines(0, log_rb_cs_BLR.freq[0], log_rb_cs_BLR.freq[-1], color='black', linestyle='dashed', lw=2)
plt.errorbar(log_rb_cs_BLR.freq, freq_lags_BLR, yerr=freq_lags_err_BLR, fmt="o", label='BLR', lw=1, color='b')
plt.errorbar(log_rb_cs_full.freq, freq_lags_full, yerr=freq_lags_err_full, fmt="o", label=f'full', lw=1, color='g')
plt.errorbar(log_rb_cs_disk.freq, freq_lags_disk, yerr=freq_lags_err_disk, fmt="o", label=f'disk', lw=1, color='r')
plt.axhline(mean_lag_full,  lw=2, label=f'full', color='g', zorder=10)
plt.axhline(mean_lag_BLR,  lw=2, label=f'BLR', color='b', zorder=10)
plt.axhline(mean_lag_Disk, lw=2, label=f'disk',color='r', zorder=10)
plt.xscale('log')
plt.xlabel('Frequency (1/days)')
plt.ylabel('Time Lag (days)')
plt.title('Time Lag vs Frequency for BLR, disk and convolution')
plt.legend()

plt.show()

# %% [markdown]
# ## Use PYCCF to find mean lag

# %%
import sys
import argparse
import PYCCF as myccf

#########################################
##Set Interpolation settings, user-specified
#########################################
lag_range = [-100, 100]  #Time lag range to consider in the CCF (days). Must be small enough that there is some overlap between light curves at that shift (i.e., if the light curves span 80 days, these values must be less than 80 days)
interp = 0.2 #Interpolation time step (days). Must be less than the average cadence of the observations, but too small will introduce noise.
nsim = 300  #Number of Monte Carlo iterations for calculation of uncertainties
mcmode = 0  #Do both FR/RSS sampling (1 = RSS only, 2 = FR only) 
sigmode = 0.2  #Choose the threshold for considering a measurement "significant". sigmode = 0.2 will consider all CCFs with r_max <= 0.2 as "failed". See code for different sigmodes.

# %%
#peforming PYCCf

mjd2 = lcfullp.time
flux2 = lcfullp.counts
mjd3 = lcBLRp.time
flux3 = lcBLRp.counts
mjd4 = lcdiskp.time
flux4 = lcdiskp.counts
mjd1 = lcp.time
flux1 = lcp.counts 
err1 = lcp.counts_err
err2 = lcfullp.counts_err
err3 = lcBLRp.counts_err
err4 = lcdiskp.counts_err

tlag_peak_12, status_peak_12, tlag_centroid_12, status_centroid_12, ccf_pack_12, max_rval_12, status_rval_12, pval_12 = myccf.peakcent(mjd1, flux1, mjd2, flux2, lag_range[0], lag_range[1], interp)
# Compare mjd1, flux1 and mjd3, flux3
tlag_peak_13, status_peak_13, tlag_centroid_13, status_centroid_13, ccf_pack_13, max_rval_13, status_rval_13, pval_13 = myccf.peakcent(mjd1, flux1, mjd3, flux3, lag_range[0], lag_range[1], interp)
# Compare mjd1, flux1 and mjd4, flux4
tlag_peak_14, status_peak_14, tlag_centroid_14, status_centroid_14, ccf_pack_14, max_rval_14, status_rval_14, pval_14 = myccf.peakcent(mjd1, flux1, mjd4, flux4, lag_range[0], lag_range[1], interp)

# Compare mjd1, flux1 and mjd2, flux2
tlags_peak_12, tlags_centroid_12, nsuccess_peak_12, nfail_peak_12, nsuccess_centroid_12, nfail_centroid_12, max_rvals_12, nfail_rvals_12, pvals_12 = myccf.xcor_mc(mjd1, flux1, abs(err1), mjd2, flux2, abs(err2), lag_range[0], lag_range[1], interp, nsim=nsim, mcmode=mcmode, sigmode=0.2)


# Compare mjd1, flux1 and mjd3, flux3
tlags_peak_13, tlags_centroid_13, nsuccess_peak_13, nfail_peak_13, nsuccess_centroid_13, nfail_centroid_13, max_rvals_13, nfail_rvals_13, pvals_13 = myccf.xcor_mc(mjd1, flux1, abs(err1), mjd3, flux3, abs(err3), lag_range[0], lag_range[1], interp, nsim=nsim, mcmode=mcmode, sigmode=0.2)


# Compare mjd1, flux1 and mjd4, flux4
tlags_peak_14, tlags_centroid_14, nsuccess_peak_14, nfail_peak_14, nsuccess_centroid_14, nfail_centroid_14, max_rvals_14, nfail_rvals_14, pvals_14 = myccf.xcor_mc(mjd1, flux1, abs(err1), mjd4, flux4, abs(err4), lag_range[0], lag_range[1], interp, nsim=nsim, mcmode=mcmode, sigmode=0.2)


lag12 = ccf_pack_12[1]
r12 = ccf_pack_12[0]
lag13 = ccf_pack_13[1]
r13 = ccf_pack_13[0]
lag14 = ccf_pack_14[1]
r14 = ccf_pack_14[0]

perclim = 84.1344746
# Out:
# Failed centroids:  0
# Failed peaks:  0
# Failed centroids:  0
# Failed peaks:  0
# Failed centroids:  0
# Failed peaks:  0

# %%
from scipy import stats

# For pair 1 and 2
centau_12 = stats.scoreatpercentile(tlags_centroid_12, 50)
centau_uperr_12 = stats.scoreatpercentile(tlags_centroid_12, 100 - perclim) - centau_12
centau_loerr_12 = centau_12 - stats.scoreatpercentile(tlags_centroid_12, perclim)
print('Centroid for 1 and 2, error: %10.3f  (+%10.3f -%10.3f)' % (centau_12, centau_loerr_12, centau_uperr_12))

peaktau_12 = stats.scoreatpercentile(tlags_peak_12, 50)
peaktau_uperr_12 = stats.scoreatpercentile(tlags_peak_12, 100 - perclim) - peaktau_12
peaktau_loerr_12 = peaktau_12 - stats.scoreatpercentile(tlags_peak_12, perclim)
print('Peak for 1 and 2, errors: %10.3f  (+%10.3f -%10.3f)' % (peaktau_12, peaktau_loerr_12, peaktau_uperr_12))

# For pair 1 and 3
centau_13 = stats.scoreatpercentile(tlags_centroid_13, 50)
centau_uperr_13 = stats.scoreatpercentile(tlags_centroid_13, 100 - perclim) - centau_13
centau_loerr_13 = centau_13 - stats.scoreatpercentile(tlags_centroid_13, perclim)
print('Centroid for 1 and 3, error: %10.3f  (+%10.3f -%10.3f)' % (centau_13, centau_loerr_13, centau_uperr_13))

peaktau_13 = stats.scoreatpercentile(tlags_peak_13, 50)
peaktau_uperr_13 = stats.scoreatpercentile(tlags_peak_13, 100 - perclim) - peaktau_13
peaktau_loerr_13 = peaktau_13 - stats.scoreatpercentile(tlags_peak_13, perclim)
print('Peak for 1 and 3, errors: %10.3f  (+%10.3f -%10.3f)' % (peaktau_13, peaktau_loerr_13, peaktau_uperr_13))

# For pair 1 and 4
centau_14 = stats.scoreatpercentile(tlags_centroid_14, 50)
centau_uperr_14 = stats.scoreatpercentile(tlags_centroid_14, 100 - perclim) - centau_14
centau_loerr_14 = centau_14 - stats.scoreatpercentile(tlags_centroid_14, perclim)
print('Centroid for 1 and 4, error: %10.3f  (+%10.3f -%10.3f)' % (centau_14, centau_loerr_14, centau_uperr_14))

peaktau_14 = stats.scoreatpercentile(tlags_peak_14, 50)
peaktau_uperr_14 = stats.scoreatpercentile(tlags_peak_14, 100 - perclim) - peaktau_14
peaktau_loerr_14 = peaktau_14 - stats.scoreatpercentile(tlags_peak_14, perclim)
print('Peak for 1 and 4, errors: %10.3f  (+%10.3f -%10.3f)' % (peaktau_14, peaktau_loerr_14, peaktau_uperr_14))
# Out:
# Centroid for 1 and 2, error:      6.005  (+    -0.179 -    -0.177)
# Peak for 1 and 2, errors:      3.600  (+     0.000 -    -0.200)
# Centroid for 1 and 3, error:     13.807  (+    -0.203 -    -0.196)
# Peak for 1 and 3, errors:     11.900  (+    -0.300 -    -0.300)
# Centroid for 1 and 4, error:      1.892  (+    -0.185 -    -0.182)
# Peak for 1 and 4, errors:      1.600  (+     0.000 -     0.000)

# %%
# Plotting
plt.figure(figsize=(6, 4))
plt.hlines(0, log_rb_cs_BLR.freq[0], log_rb_cs_BLR.freq[-1], color='black', linestyle='dashed', lw=2)
plt.errorbar(log_rb_cs_BLR.freq, freq_lags_BLR, yerr=freq_lags_err_BLR, fmt="o", label='BLR', lw=1, color='b')
plt.errorbar(log_rb_cs_full.freq, freq_lags_full, yerr=freq_lags_err_full, fmt="o", label=f'full', lw=1, color='g')
plt.errorbar(log_rb_cs_disk.freq, freq_lags_disk, yerr=freq_lags_err_disk, fmt="o", label=f'disk', lw=1, color='r')
plt.axhline(tlag_centroid_12, lw=2, color='g', zorder=1)
#plt.errorbar(x=0, y=tlag_centroid_12, yerr=[[centau_uperr_12], [centau_loerr_12]], color='red', fmt='o', label='Error Bar (1 and 2)')
plt.axhline(tlag_centroid_13, lw=2, color='blue', zorder=1)
#plt.errorbar(x=0, y=tlag_centroid_13, yerr=[[centau_uperr_13], [centau_loerr_13]], color='blue', fmt='o', label='Error Bar (1 and 3)')
plt.axhline(tlag_centroid_14,  lw=2, color='r', zorder=1)
#plt.errorbar(x=0, y=tlag_centroid_14, yerr=[[centau_uperr_14], [centau_loerr_14]], color='green', fmt='o', label='Error Bar (1 and 4)')
plt.axhline(mean_lag_full, linestyle='--', lw=2,  color='g', zorder=1)
plt.axhline(mean_lag_BLR, linestyle='--', lw=2, color='b', zorder=1)
plt.axhline(mean_lag_Disk, linestyle='--', lw=2, color='r', zorder=1)
plt.xscale('log')
plt.xlabel('Frequency (1/days)',fontsize=15)
plt.ylabel('Time Lag (days)',fontsize=15)

plt.title('Time Lag vs Frequency for BLR, disk and convolution',fontsize=15)
legend = plt.legend(loc='upper right')
plt.setp(legend.get_texts(), zorder=10) 


plt.show()
