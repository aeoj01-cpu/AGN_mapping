# %%
pip install astropy scipy matplotlib numpy h5py tqdm numba pint-pulsar emcee corner statsmodels pyfftw tbb
# Out:
# Requirement already satisfied: astropy in /opt/conda/lib/python3.11/site-packages (6.0.1)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.11/site-packages (1.11.3)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.11/site-packages (3.8.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (1.24.4)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.11/site-packages (3.10.0)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.11/site-packages (4.66.1)
# Requirement already satisfied: numba in /opt/conda/lib/python3.11/site-packages (0.57.1)
# Requirement already satisfied: pint-pulsar in /opt/conda/lib/python3.11/site-packages (0.9.8)
# Requirement already satisfied: emcee in /opt/conda/lib/python3.11/site-packages (3.1.4)
# Requirement already satisfied: corner in /opt/conda/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.11/site-packages (0.14.0)
# Requirement already satisfied: pyfftw in /opt/conda/lib/python3.11/site-packages (0.13.1)
# Requirement already satisfied: tbb in /opt/conda/lib/python3.11/site-packages (2021.12.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /opt/conda/lib/python3.11/site-packages (from astropy) (2.0.1.1)
# Requirement already satisfied: astropy-iers-data>=0.2024.2.26.0.28.55 in /opt/conda/lib/python3.11/site-packages (from astropy) (0.2024.4.1.0.33.14)
# Requirement already satisfied: PyYAML>=3.13 in /opt/conda/lib/python3.11/site-packages (from astropy) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /opt/conda/lib/python3.11/site-packages (from astropy) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in /opt/conda/lib/python3.11/site-packages (from numba) (0.40.1)
# Requirement already satisfied: jplephem>=2.6 in /opt/conda/lib/python3.11/site-packages (from pint-pulsar) (2.21)
# Requirement already satisfied: uncertainties in /opt/conda/lib/python3.11/site-packages (from pint-pulsar) (3.1.7)
# Requirement already satisfied: loguru in /opt/conda/lib/python3.11/site-packages (from pint-pulsar) (0.7.2)
# Requirement already satisfied: nestle>=0.2.0 in /opt/conda/lib/python3.11/site-packages (from pint-pulsar) (0.2.0)
# Requirement already satisfied: pandas>=1.0 in /opt/conda/lib/python3.11/site-packages (from statsmodels) (2.1.1)
# Requirement already satisfied: patsy>=0.5.2 in /opt/conda/lib/python3.11/site-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.0->statsmodels) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.11/site-packages (from pandas>=1.0->statsmodels) (2023.3)
# Requirement already satisfied: six in /opt/conda/lib/python3.11/site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.11/site-packages (from uncertainties->pint-pulsar) (0.18.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pytest pytest-astropy jinja2 docutils sphinx-astropy nbsphinx pandoc ipython jupyter notebook towncrier tox black
# Out:
# Requirement already satisfied: pytest in /opt/conda/lib/python3.11/site-packages (8.1.1)
# Requirement already satisfied: pytest-astropy in /opt/conda/lib/python3.11/site-packages (0.11.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: docutils in /opt/conda/lib/python3.11/site-packages (0.20.1)
# Requirement already satisfied: sphinx-astropy in /opt/conda/lib/python3.11/site-packages (1.9.1)
# Requirement already satisfied: nbsphinx in /opt/conda/lib/python3.11/site-packages (0.9.3)
# Requirement already satisfied: pandoc in /opt/conda/lib/python3.11/site-packages (2.3)
# Requirement already satisfied: ipython in /opt/conda/lib/python3.11/site-packages (8.16.1)
# Requirement already satisfied: jupyter in /opt/conda/lib/python3.11/site-packages (1.0.0)
# Requirement already satisfied: notebook in /opt/conda/lib/python3.11/site-packages (6.5.6)
# Requirement already satisfied: towncrier in /opt/conda/lib/python3.11/site-packages (23.11.0)
# Requirement already satisfied: tox in /opt/conda/lib/python3.11/site-packages (4.14.2)
# Requirement already satisfied: black in /opt/conda/lib/python3.11/site-packages (24.3.0)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.11/site-packages (from pytest) (2.0.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from pytest) (23.2)
# Requirement already satisfied: pluggy<2.0,>=1.4 in /opt/conda/lib/python3.11/site-packages (from pytest) (1.4.0)
# Requirement already satisfied: pytest-doctestplus>=1.0.0 in /opt/conda/lib/python3.11/site-packages (from pytest-astropy) (1.2.1)
# Requirement already satisfied: pytest-remotedata>=0.4.1 in /opt/conda/lib/python3.11/site-packages (from pytest-astropy) (0.4.1)
# Requirement already satisfied: pytest-astropy-header>=0.2.2 in /opt/conda/lib/python3.11/site-packages (from pytest-astropy) (0.2.2)
# Requirement already satisfied: pytest-arraydiff>=0.5 in /opt/conda/lib/python3.11/site-packages (from pytest-astropy) (0.6.1)
# Requirement already satisfied: pytest-filter-subpackage>=0.1.2 in /opt/conda/lib/python3.11/site-packages (from pytest-astropy) (0.2.0)
# Requirement already satisfied: pytest-cov>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from pytest-astropy) (5.0.0)
# Requirement already satisfied: pytest-mock>=2.0 in /opt/conda/lib/python3.11/site-packages (from pytest-astropy) (3.14.0)
# Requirement already satisfied: attrs>=19.2.0 in /opt/conda/lib/python3.11/site-packages (from pytest-astropy) (23.1.0)
# Requirement already satisfied: hypothesis>=5.1 in /opt/conda/lib/python3.11/site-packages (from pytest-astropy) (6.100.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2) (2.1.3)
# Requirement already satisfied: sphinx>=3.0.0 in /opt/conda/lib/python3.11/site-packages (from sphinx-astropy) (7.2.6)
# Requirement already satisfied: astropy-sphinx-theme in /opt/conda/lib/python3.11/site-packages (from sphinx-astropy) (1.1)
# Requirement already satisfied: numpydoc in /opt/conda/lib/python3.11/site-packages (from sphinx-astropy) (1.7.0)
# Requirement already satisfied: sphinx-automodapi in /opt/conda/lib/python3.11/site-packages (from sphinx-astropy) (0.17.0)
# Requirement already satisfied: sphinx-gallery in /opt/conda/lib/python3.11/site-packages (from sphinx-astropy) (0.15.0)
# Requirement already satisfied: sphinxcontrib-jquery in /opt/conda/lib/python3.11/site-packages (from sphinx-astropy) (4.1)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.11/site-packages (from sphinx-astropy) (10.1.0)
# Requirement already satisfied: nbconvert!=5.4 in /opt/conda/lib/python3.11/site-packages (from nbsphinx) (7.9.2)
# Requirement already satisfied: traitlets>=5 in /opt/conda/lib/python3.11/site-packages (from nbsphinx) (5.11.2)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.11/site-packages (from nbsphinx) (5.9.2)
# Requirement already satisfied: plumbum in /opt/conda/lib/python3.11/site-packages (from pandoc) (1.8.2)
# Requirement already satisfied: ply in /opt/conda/lib/python3.11/site-packages (from pandoc) (3.11)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.11/site-packages (from ipython) (0.2.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.11/site-packages (from ipython) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.11/site-packages (from ipython) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.11/site-packages (from ipython) (0.1.6)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.11/site-packages (from ipython) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /opt/conda/lib/python3.11/site-packages (from ipython) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from ipython) (2.16.1)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.11/site-packages (from ipython) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.11/site-packages (from ipython) (4.8.0)
# Requirement already satisfied: qtconsole in /opt/conda/lib/python3.11/site-packages (from jupyter) (5.5.1)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.11/site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.11/site-packages (from jupyter) (6.25.2)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.11/site-packages (from jupyter) (8.1.1)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.11/site-packages (from notebook) (6.3.3)
# Requirement already satisfied: pyzmq<25,>=17 in /opt/conda/lib/python3.11/site-packages (from notebook) (24.0.1)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.11/site-packages (from notebook) (23.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /opt/conda/lib/python3.11/site-packages (from notebook) (5.4.0)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /opt/conda/lib/python3.11/site-packages (from notebook) (7.4.9)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.11/site-packages (from notebook) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/conda/lib/python3.11/site-packages (from notebook) (1.5.8)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.11/site-packages (from notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from notebook) (0.17.1)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.11/site-packages (from notebook) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.11/site-packages (from notebook) (1.0.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.11/site-packages (from towncrier) (8.1.7)
# Requirement already satisfied: incremental in /opt/conda/lib/python3.11/site-packages (from towncrier) (22.10.0)
# Requirement already satisfied: cachetools>=5.3.2 in /opt/conda/lib/python3.11/site-packages (from tox) (5.3.2)
# Requirement already satisfied: chardet>=5.2 in /opt/conda/lib/python3.11/site-packages (from tox) (5.2.0)
# Requirement already satisfied: colorama>=0.4.6 in /opt/conda/lib/python3.11/site-packages (from tox) (0.4.6)
# Requirement already satisfied: filelock>=3.13.1 in /opt/conda/lib/python3.11/site-packages (from tox) (3.13.1)
# Requirement already satisfied: platformdirs>=4.1 in /opt/conda/lib/python3.11/site-packages (from tox) (4.2.0)
# Requirement already satisfied: pyproject-api>=1.6.1 in /opt/conda/lib/python3.11/site-packages (from tox) (1.6.1)
# Requirement already satisfied: virtualenv>=20.25 in /opt/conda/lib/python3.11/site-packages (from tox) (20.25.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /opt/conda/lib/python3.11/site-packages (from black) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /opt/conda/lib/python3.11/site-packages (from black) (0.12.1)
# Requirement already satisfied: sortedcontainers<3.0.0,>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from hypothesis>=5.1->pytest-astropy) (2.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.11/site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.11/site-packages (from jupyter-client<8,>=5.3.4->notebook) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from jupyter-client<8,>=5.3.4->notebook) (2.8.2)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook) (1.24.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/conda/lib/python3.11/site-packages (from nbclassic>=0.4.7->notebook) (0.2.3)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.11/site-packages (from nbconvert!=5.4->nbsphinx) (4.12.2)
# Requirement already satisfied: bleach!=5.0.0 in /opt/conda/lib/python3.11/site-packages (from nbconvert!=5.4->nbsphinx) (6.1.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.11/site-packages (from nbconvert!=5.4->nbsphinx) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.11/site-packages (from nbconvert!=5.4->nbsphinx) (0.2.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/conda/lib/python3.11/site-packages (from nbconvert!=5.4->nbsphinx) (3.0.1)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/conda/lib/python3.11/site-packages (from nbconvert!=5.4->nbsphinx) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.11/site-packages (from nbconvert!=5.4->nbsphinx) (1.5.0)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.11/site-packages (from nbconvert!=5.4->nbsphinx) (1.2.1)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.11/site-packages (from nbformat->nbsphinx) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.11/site-packages (from nbformat->nbsphinx) (4.19.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.11/site-packages (from pexpect>4.3->ipython) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython) (0.2.8)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (from pytest-arraydiff>=0.5->pytest-astropy) (1.24.4)
# Requirement already satisfied: coverage>=5.2.1 in /opt/conda/lib/python3.11/site-packages (from coverage[toml]>=5.2.1->pytest-cov>=2.3.1->pytest-astropy) (7.4.4)
# Requirement already satisfied: setuptools>=30.3.0 in /opt/conda/lib/python3.11/site-packages (from pytest-doctestplus>=1.0.0->pytest-astropy) (68.2.2)
# Requirement already satisfied: sphinxcontrib-applehelp in /opt/conda/lib/python3.11/site-packages (from sphinx>=3.0.0->sphinx-astropy) (1.0.8)
# Requirement already satisfied: sphinxcontrib-devhelp in /opt/conda/lib/python3.11/site-packages (from sphinx>=3.0.0->sphinx-astropy) (1.0.6)
# Requirement already satisfied: sphinxcontrib-jsmath in /opt/conda/lib/python3.11/site-packages (from sphinx>=3.0.0->sphinx-astropy) (1.0.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /opt/conda/lib/python3.11/site-packages (from sphinx>=3.0.0->sphinx-astropy) (2.0.5)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /opt/conda/lib/python3.11/site-packages (from sphinx>=3.0.0->sphinx-astropy) (1.1.10)
# Requirement already satisfied: sphinxcontrib-qthelp in /opt/conda/lib/python3.11/site-packages (from sphinx>=3.0.0->sphinx-astropy) (1.0.7)
# Requirement already satisfied: snowballstemmer>=2.0 in /opt/conda/lib/python3.11/site-packages (from sphinx>=3.0.0->sphinx-astropy) (2.2.0)
# Requirement already satisfied: babel>=2.9 in /opt/conda/lib/python3.11/site-packages (from sphinx>=3.0.0->sphinx-astropy) (2.13.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /opt/conda/lib/python3.11/site-packages (from sphinx>=3.0.0->sphinx-astropy) (0.7.16)
# Requirement already satisfied: imagesize>=1.3 in /opt/conda/lib/python3.11/site-packages (from sphinx>=3.0.0->sphinx-astropy) (1.4.1)
# Requirement already satisfied: requests>=2.25.0 in /opt/conda/lib/python3.11/site-packages (from sphinx>=3.0.0->sphinx-astropy) (2.31.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /opt/conda/lib/python3.11/site-packages (from virtualenv>=20.25->tox) (0.3.8)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.11/site-packages (from argon2-cffi->notebook) (21.2.0)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter) (0.1.4)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter) (1.8.0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.11/site-packages (from ipykernel->jupyter) (5.9.5)
# Requirement already satisfied: widgetsnbextension~=4.0.9 in /opt/conda/lib/python3.11/site-packages (from ipywidgets->jupyter) (4.0.9)
# Requirement already satisfied: jupyterlab-widgets~=3.0.9 in /opt/conda/lib/python3.11/site-packages (from ipywidgets->jupyter) (3.0.9)
# Requirement already satisfied: tabulate>=0.8.10 in /opt/conda/lib/python3.11/site-packages (from numpydoc->sphinx-astropy) (0.9.0)
# Requirement already satisfied: qtpy>=2.4.0 in /opt/conda/lib/python3.11/site-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython) (2.4.0)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.11/site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.11/site-packages (from asttokens>=2.1.0->stack-data->ipython) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.11/site-packages (from bleach!=5.0.0->nbconvert!=5.4->nbsphinx) (0.5.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.11/site-packages (from jsonschema>=2.6->nbformat->nbsphinx) (0.10.6)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (3.7.1)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.11/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (1.6.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.25.0->sphinx>=3.0.0->sphinx-astropy) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.25.0->sphinx>=3.0.0->sphinx-astropy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.25.0->sphinx>=3.0.0->sphinx-astropy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.25.0->sphinx>=3.0.0->sphinx-astropy) (2024.2.2)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.11/site-packages (from beautifulsoup4->nbconvert!=5.4->nbsphinx) (2.5)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.11/site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook) (1.3.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.11/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install stingray PyROA emcee tabulate corner astropy
# Out:
# Requirement already satisfied: stingray in /opt/conda/lib/python3.11/site-packages (2.0.0)
# Requirement already satisfied: PyROA in /opt/conda/lib/python3.11/site-packages (3.2.2)
# Requirement already satisfied: emcee in /opt/conda/lib/python3.11/site-packages (3.1.4)
# Requirement already satisfied: tabulate in /opt/conda/lib/python3.11/site-packages (0.9.0)
# Requirement already satisfied: corner in /opt/conda/lib/python3.11/site-packages (2.2.2)
# Requirement already satisfied: astropy in /opt/conda/lib/python3.11/site-packages (6.0.1)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.11/site-packages (from stingray) (68.2.2)
# Requirement already satisfied: numpy>=1.17.0 in /opt/conda/lib/python3.11/site-packages (from stingray) (1.24.4)
# Requirement already satisfied: scipy>=1.1.0 in /opt/conda/lib/python3.11/site-packages (from stingray) (1.11.3)
# Requirement already satisfied: matplotlib!=3.4.0,>=3.0 in /opt/conda/lib/python3.11/site-packages (from stingray) (3.8.0)
# Requirement already satisfied: pyerfa>=2.0.1.1 in /opt/conda/lib/python3.11/site-packages (from astropy) (2.0.1.1)
# Requirement already satisfied: astropy-iers-data>=0.2024.2.26.0.28.55 in /opt/conda/lib/python3.11/site-packages (from astropy) (0.2024.4.1.0.33.14)
# Requirement already satisfied: PyYAML>=3.13 in /opt/conda/lib/python3.11/site-packages (from astropy) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /opt/conda/lib/python3.11/site-packages (from astropy) (23.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.4.0,>=3.0->stingray) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.4.0,>=3.0->stingray) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.4.0,>=3.0->stingray) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.4.0,>=3.0->stingray) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.4.0,>=3.0->stingray) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.4.0,>=3.0->stingray) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.11/site-packages (from matplotlib!=3.4.0,>=3.0->stingray) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.4.0,>=3.0->stingray) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cd /home/jovyan/AS4013/PYCCF
# Out:
# /home/jovyan/AS4013/PYCCF

# %%
import shutil

# Replace '/path/to/work_directory' with your actual work directory
work_directory = '/home/jovyan/AS4013'

# Copy xcorspc.so and PYCCF.py to the work directory
shutil.copy('xcorspc.pyx', work_directory)
shutil.copy('PYCCF.py', work_directory)
# Out:
# '/home/jovyan/AS4013/PYCCF.py'

# %%
import numpy as np
from stingray import Lightcurve, Crossspectrum, AveragedCrossspectrum
import sys
import argparse
import PYCCF as myccf
import random
from scipy import stats 
import os
import PyROA
import matplotlib.pyplot as plt
import psi
from scipy.integrate import simps

import importlib
importlib.reload(psi)
# Out:
# /opt/conda/lib/python3.11/site-packages/h5py/__init__.py:36: UserWarning: h5py is running against HDF5 1.14.3 when it was built against 1.14.2, this may cause problems
#   _warn(("h5py is running against HDF5 {0} when it was built against {1}, "
# <module 'psi' from '/home/jovyan/AS4013/psi.py'>

# %%
#import flux and time here 
#make sure to changes time to days 
#time = np.array(column1_data)/(24*3600)
#flux = np.array(column2_data)

directory_path = '/home/jovyan/AS4013'
file_name = 'lc30mins.dat'
file_path = os.path.join(directory_path, file_name)

column_index1 = 0  
column_index2 = 1

with open(file_path, 'r') as file:
    # Read all lines
    lines = file.readlines()
    data_lines = lines[1:]
    
   # Extract the desired columns from each line and convert to float
    column1_data = [float(line.split()[column_index1]) for line in data_lines]
    column2_data = [float(line.split()[column_index2]) for line in data_lines]

time = np.array(column1_data)/(24*3600)
flux = np.array(column2_data)

# %%
#########################################
##Set Interpolation settings, user-specified
#########################################
lag_range = [-100, 100]  #Time lag range to consider in the CCF (days). Must be small enough that there is some overlap between light curves at that shift (i.e., if the light curves span 80 days, these values must be less than 80 days)
interp = 0.2 #Interpolation time step (days). Must be less than the average cadence of the observations, but too small will introduce noise.
nsim = 100  #Number of Monte Carlo iterations for calculation of uncertainties
mcmode = 0  #Do both FR/RSS sampling (1 = RSS only, 2 = FR only) 
sigmode = 0.2  #Choose the threshold for considering a measurement "significant". sigmode = 0.2 will consider all CCFs with r_max <= 0.2 as "failed". See code for different sigmodes.
#########################################
##Set freq-lag settings, user-specified
#########################################
window = 1  #width of window function PYROA 
cs_binning = 100 #averaged cross spectrum binning 
error_in_flux = 0.01 #define percentage error in flux 
SN = 100 #sound to noise ratio 
sampling_rate = 1 #how many samples are taken per day 
sampling_loss = 0.2 # the amount of data lost due to sampling issues
final_length = 350 #length of final array in days 
dt = 1800 #each interval in seconds 
S = 1.0 #sd of BLR function
M = np.log(13.9) # mean of BLR function


exposure = len(time) #length of full array 
seconds_day = 86400
original_length = exposure/(seconds_day/dt)

times = (np.linspace(-exposure, exposure+1, num = exposure*2)*dt)/(24*3600) # converted to days

def disk(times,wavelength,A1):#define a response function for the accretion disk  
    bhmass = 10**7.22       # Msol
    mdot = 0.708         # Msol/yr
    inc = 58           # inclination, degrees
    combi_psi = psi.pytfb_sub(times,1e8,mdot,wavelength,inc,norm=1)
    combi_psi[np.isnan(combi_psi)]=0
    # normalise 
    normi = simps(combi_psi,x=times)
    return A1*(combi_psi/normi)
 

# Define BLR response function
def BLR(times,A2): 
    #log normal distribution
    BLR_array = A2/(S*np.sqrt(2*np.pi*times))*np.exp(-(np.log(times)-M)**2/(2*(S**2)))
    BLR_array[np.isnan(BLR_array)]=0
    return  BLR_array

# %%
#define them by wavelenth and BLR fraction
BLR_array_1 = BLR(times, 0.5) 
combi_psi_1 = disk(times, 4770, (0.5))

#mixture model 
BLR_array = BLR_array_1 + combi_psi_1

### Perform convolution
signal4_BLR = np.convolve(flux, BLR_array, mode='full')
start_index = int((len(signal4_BLR) - len(flux)) / 2)
end_index = start_index + len(flux)
#index as we used a full convolution
signal4_BLR = signal4_BLR[start_index:end_index]

#create the array to be only over area of interest
interval = (original_length-final_length)/2
start = int(seconds_day/dt*interval)
end = int(seconds_day/dt*(original_length-interval))
# Out:
# /tmp/ipykernel_2298/4132634249.py:44: RuntimeWarning: invalid value encountered in sqrt
#   BLR_array = A2/(S*np.sqrt(2*np.pi*times))*np.exp(-(np.log(times)-M)**2/(2*(S**2)))
# /tmp/ipykernel_2298/4132634249.py:44: RuntimeWarning: invalid value encountered in log
#   BLR_array = A2/(S*np.sqrt(2*np.pi*times))*np.exp(-(np.log(times)-M)**2/(2*(S**2)))

# %% [markdown]
# ### Create Light curves and response functions

# %%
signal4_BLR = signal4_BLR[start:end]
flux = flux[start:end]
time = time[start:end]

new_times = []
new_flux_BLR = []
new_flux_lc = []

#sample randomly
for i in range(final_length):
    
    random_number = random.randint(0, seconds_day/dt)
    index = int(i*seconds_day/dt) + random_number
    
    new_times.append(time[index])
    new_flux_lc.append(flux[index])
    new_flux_BLR.append(signal4_BLR[index])


lost_data = int(len(new_flux_lc)*sampling_loss)  

#remove lost data
for i in range(lost_data):
    
    random_number = random.randint(0,len(new_times)-1)
    new_flux_lc.pop(random_number)
    new_times.pop(random_number)
    new_flux_BLR.pop(random_number)

#create lightcurves
lc_BLR = Lightcurve(new_times,new_flux_BLR )
lc = Lightcurve(new_times,new_flux_lc)

lc_test_BLR =Lightcurve(time,signal4_BLR)
lc_test = Lightcurve(time,flux)    

#getting mean 
mean_lc_BLR = np.mean(lc_BLR.counts)
mean_lc = np.mean(lc.counts)
mean_lc_test_BLR = np.mean(lc_test_BLR.counts)
mean_lc_test = np.mean(lc_test.counts)

#getting standard deviation
sd_lc_BLR = np.std(lc_BLR.counts)
sd_lc = np.std(lc.counts)
sd_lc_test_BLR = np.std(lc_test_BLR.counts)
sd_lc_test = np.std(lc_test.counts)

#normalising
lc_BLR_N = (lc_BLR.counts-mean_lc_BLR)/sd_lc_BLR
lc_N = (lc.counts-mean_lc)/sd_lc
lc_test_BLR_N = (lc_test_BLR.counts-mean_lc_test_BLR)/sd_lc_test_BLR
lc_test_N = (lc_test.counts-mean_lc_test)/sd_lc_test

# and adding noise
lc_test_BLR_N = np.random.normal(lc_test_BLR_N,abs(lc_test_BLR_N/SN))
lc_test_N = np.random.normal(lc_test_N,abs(lc_test_N/SN))

#create normalised lightcurves
lc_test_BLR_N = Lightcurve(lc_test_BLR.time,lc_test_BLR_N)
lc_test_N = Lightcurve(lc_test.time,lc_test_N)

#create errors in flux 
lc_test_N.counts_err = abs(lc_test_N.counts*error_in_flux)
lc_test_BLR_N.counts_err = abs(lc_test_BLR_N.counts*error_in_flux)

#average cross spectrum 
avg_cs_BLR = AveragedCrossspectrum.from_lightcurve(lc_test_BLR_N, lc_test_N, cs_binning)

#logarithmically rebin 
log_rb_cs = avg_cs_BLR.rebin_log(f=1.2)

#define time lags 
freq_lags, freq_lags_err = log_rb_cs.time_lag()
# Out:
# /opt/conda/lib/python3.11/site-packages/stingray/utils.py:406: UserWarning: SIMON says: Bin sizes in input time array aren't equal throughout! This could cause problems with Fourier transforms. Please make the input time evenly sampled.Only use with LombScargleCrossspectrum, LombScarglePowerspectrum and QPO using GPResult
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# 3it [00:00, 460.90it/s]
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1914: RuntimeWarning: invalid value encountered in sqrt
#   n_ph = np.sqrt(n_ph1 * n_ph2)
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1125: UserWarning: n_ave is below 30. Please note that the error bars on the quantities derived from the cross spectrum are only reliable for a large number of averaged powers.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1139: RuntimeWarning: invalid value encountered in sqrt
#   dRe = dIm = dG = np.sqrt(power_over_2n * (seg_power - frac))
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1141: RuntimeWarning: invalid value encountered in sqrt
#   dphi = np.sqrt(
# /opt/conda/lib/python3.11/site-packages/stingray/crossspectrum.py:2912: UserWarning: Some error bars in the Averaged Crossspectrum are invalid.Defaulting to sqrt(2 / M) in Leahy norm, rescaled to the appropriate norm.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/stingray/crossspectrum.py:2917: RuntimeWarning: invalid value encountered in sqrt
#   Nph = np.sqrt(cs.nphots1 * cs.nphots2)
# /opt/conda/lib/python3.11/site-packages/stingray/utils.py:406: UserWarning: SIMON says: Number of segments used in averaging is significantly low. The result might not follow the expected statistical distributions.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)

# %% [markdown]
# ### add noise, add error then interpolate with PYROA and find cross spectrum and frequency resolved lags for each value of noise

# %%
SN = 100
lc_BLR_N_1 = np.random.normal(lc_BLR_N, abs(lc_BLR_N/SN))
lc_N_1 = np.random.normal(lc_N, abs(lc_N/SN))
lc_BLR_N_1 = Lightcurve(lc_BLR.time, lc_BLR_N_1)
lc_N_1 = Lightcurve(lc.time, lc_N_1)
lc_N_1.counts_err = abs(lc_N_1.counts*error_in_flux)
lc_BLR_N_1.counts_err = abs(lc_BLR_N_1.counts*error_in_flux)
(lc_P_times_1, lc_P_counts_1, lc_P_err_1) = PyROA.RunningOptimalAverage(lc_N_1.time, lc_N_1.counts, lc_N_1.counts_err, window)
(lc_BLR_P_times_1, lc_BLR_P_counts_1, lc_BLR_P_err_1) = PyROA.RunningOptimalAverage(lc_BLR_N_1.time, lc_BLR_N_1.counts, lc_BLR_N_1.counts_err, window)
lcp_1 = Lightcurve(lc_P_times_1, lc_P_counts_1, err=lc_P_err_1)
lcBLRp_1 = Lightcurve(lc_BLR_P_times_1, lc_BLR_P_counts_1, err=lc_BLR_P_err_1)
avg_cs_BLR_P_1 = AveragedCrossspectrum.from_lightcurve(lcBLRp_1, lcp_1, cs_binning)
log_rb_cs_P_1 = avg_cs_BLR_P_1.rebin_log(f=1.2)

freq_lags_P_1, freq_lags_err_P_1 = log_rb_cs_P_1.time_lag()
# Out:
# /opt/conda/lib/python3.11/site-packages/stingray/utils.py:406: UserWarning: SIMON says: Bin sizes in input time array aren't equal throughout! This could cause problems with Fourier transforms. Please make the input time evenly sampled.Only use with LombScargleCrossspectrum, LombScarglePowerspectrum and QPO using GPResult
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# 3it [00:00, 954.05it/s]
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1914: RuntimeWarning: invalid value encountered in sqrt
#   n_ph = np.sqrt(n_ph1 * n_ph2)
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1125: UserWarning: n_ave is below 30. Please note that the error bars on the quantities derived from the cross spectrum are only reliable for a large number of averaged powers.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1139: RuntimeWarning: invalid value encountered in sqrt
#   dRe = dIm = dG = np.sqrt(power_over_2n * (seg_power - frac))
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1141: RuntimeWarning: invalid value encountered in sqrt
#   dphi = np.sqrt(
# /opt/conda/lib/python3.11/site-packages/stingray/crossspectrum.py:2912: UserWarning: Some error bars in the Averaged Crossspectrum are invalid.Defaulting to sqrt(2 / M) in Leahy norm, rescaled to the appropriate norm.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/stingray/crossspectrum.py:2917: RuntimeWarning: invalid value encountered in sqrt
#   Nph = np.sqrt(cs.nphots1 * cs.nphots2)
# /opt/conda/lib/python3.11/site-packages/stingray/utils.py:406: UserWarning: SIMON says: Number of segments used in averaging is significantly low. The result might not follow the expected statistical distributions.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)

# %%
SN = 5
lc_BLR_N_20 = np.random.normal(lc_BLR_N, abs(lc_BLR_N/SN))
lc_N_20 = np.random.normal(lc_N, abs(lc_N/SN))
lc_BLR_N_20 = Lightcurve(lc_BLR.time, lc_BLR_N_20)
lc_N_20 = Lightcurve(lc.time, lc_N_20)
lc_N_20.counts_err = abs(lc_N_20.counts*error_in_flux)
lc_BLR_N_20.counts_err = abs(lc_BLR_N_20.counts*error_in_flux)
(lc_P_times_20, lc_P_counts_20, lc_P_err_20) = PyROA.RunningOptimalAverage(lc_N_20.time, lc_N_20.counts, lc_N_20.counts_err, window)
(lc_BLR_P_times_20, lc_BLR_P_counts_20, lc_BLR_P_err_20) = PyROA.RunningOptimalAverage(lc_BLR_N_20.time, lc_BLR_N_20.counts, lc_BLR_N_20.counts_err, window)
lcp_20 = Lightcurve(lc_P_times_20, lc_P_counts_20, err=lc_P_err_20)
lcBLRp_20 = Lightcurve(lc_BLR_P_times_20, lc_BLR_P_counts_20, err=lc_BLR_P_err_20)
avg_cs_BLR_P_20 = AveragedCrossspectrum.from_lightcurve(lcBLRp_20, lcp_20, cs_binning)
log_rb_cs_P_20 = avg_cs_BLR_P_20.rebin_log(f=1.2)

freq_lags_P_20, freq_lags_err_P_20 = log_rb_cs_P_20.time_lag()
# Out:
# /opt/conda/lib/python3.11/site-packages/stingray/utils.py:406: UserWarning: SIMON says: Bin sizes in input time array aren't equal throughout! This could cause problems with Fourier transforms. Please make the input time evenly sampled.Only use with LombScargleCrossspectrum, LombScarglePowerspectrum and QPO using GPResult
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# 3it [00:00, 1761.08it/s]
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1914: RuntimeWarning: invalid value encountered in sqrt
#   n_ph = np.sqrt(n_ph1 * n_ph2)
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1125: UserWarning: n_ave is below 30. Please note that the error bars on the quantities derived from the cross spectrum are only reliable for a large number of averaged powers.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1139: RuntimeWarning: invalid value encountered in sqrt
#   dRe = dIm = dG = np.sqrt(power_over_2n * (seg_power - frac))
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1141: RuntimeWarning: invalid value encountered in sqrt
#   dphi = np.sqrt(
# /opt/conda/lib/python3.11/site-packages/stingray/crossspectrum.py:2912: UserWarning: Some error bars in the Averaged Crossspectrum are invalid.Defaulting to sqrt(2 / M) in Leahy norm, rescaled to the appropriate norm.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/stingray/crossspectrum.py:2917: RuntimeWarning: invalid value encountered in sqrt
#   Nph = np.sqrt(cs.nphots1 * cs.nphots2)
# /opt/conda/lib/python3.11/site-packages/stingray/utils.py:406: UserWarning: SIMON says: Number of segments used in averaging is significantly low. The result might not follow the expected statistical distributions.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)

# %%
SN = 10
lc_BLR_N_10 = np.random.normal(lc_BLR_N, abs(lc_BLR_N/SN))
lc_N_10 = np.random.normal(lc_N, abs(lc_N/SN))
lc_BLR_N_10 = Lightcurve(lc_BLR.time, lc_BLR_N_10)
lc_N_10 = Lightcurve(lc.time, lc_N_10)
lc_N_10.counts_err = abs(lc_N_10.counts*error_in_flux)
lc_BLR_N_10.counts_err = abs(lc_BLR_N_10.counts*error_in_flux)
(lc_P_times_10, lc_P_counts_10, lc_P_err_10) = PyROA.RunningOptimalAverage(lc_N_10.time, lc_N_10.counts, lc_N_10.counts_err, window)
(lc_BLR_P_times_10, lc_BLR_P_counts_10, lc_BLR_P_err_10) = PyROA.RunningOptimalAverage(lc_BLR_N_10.time, lc_BLR_N_10.counts, lc_BLR_N_10.counts_err, window)
lcp_10 = Lightcurve(lc_P_times_10, lc_P_counts_10, err=lc_P_err_10)
lcBLRp_10 = Lightcurve(lc_BLR_P_times_10, lc_BLR_P_counts_10, err=lc_BLR_P_err_10)
avg_cs_BLR_P_10 = AveragedCrossspectrum.from_lightcurve(lcBLRp_10, lcp_10, cs_binning)
log_rb_cs_P_10 = avg_cs_BLR_P_10.rebin_log(f=1.2)

freq_lags_P_10, freq_lags_err_P_10 = log_rb_cs_P_10.time_lag()
# Out:
# /opt/conda/lib/python3.11/site-packages/stingray/utils.py:406: UserWarning: SIMON says: Bin sizes in input time array aren't equal throughout! This could cause problems with Fourier transforms. Please make the input time evenly sampled.Only use with LombScargleCrossspectrum, LombScarglePowerspectrum and QPO using GPResult
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# 3it [00:00, 1774.24it/s]
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1914: RuntimeWarning: invalid value encountered in sqrt
#   n_ph = np.sqrt(n_ph1 * n_ph2)
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1125: UserWarning: n_ave is below 30. Please note that the error bars on the quantities derived from the cross spectrum are only reliable for a large number of averaged powers.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1139: RuntimeWarning: invalid value encountered in sqrt
#   dRe = dIm = dG = np.sqrt(power_over_2n * (seg_power - frac))
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1141: RuntimeWarning: invalid value encountered in sqrt
#   dphi = np.sqrt(
# /opt/conda/lib/python3.11/site-packages/stingray/crossspectrum.py:2912: UserWarning: Some error bars in the Averaged Crossspectrum are invalid.Defaulting to sqrt(2 / M) in Leahy norm, rescaled to the appropriate norm.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/stingray/crossspectrum.py:2917: RuntimeWarning: invalid value encountered in sqrt
#   Nph = np.sqrt(cs.nphots1 * cs.nphots2)
# /opt/conda/lib/python3.11/site-packages/stingray/utils.py:406: UserWarning: SIMON says: Number of segments used in averaging is significantly low. The result might not follow the expected statistical distributions.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)

# %%
SN = 20
lc_BLR_N_5 = np.random.normal(lc_BLR_N, abs(lc_BLR_N/SN))
lc_N_5 = np.random.normal(lc_N, abs(lc_N/SN))
lc_BLR_N_5 = Lightcurve(lc_BLR.time, lc_BLR_N_5)
lc_N_5 = Lightcurve(lc.time, lc_N_5)
lc_N_5.counts_err = abs(lc_N_5.counts*error_in_flux)
lc_BLR_N_5.counts_err = abs(lc_BLR_N_5.counts*error_in_flux)
(lc_P_times_5, lc_P_counts_5, lc_P_err_5) = PyROA.RunningOptimalAverage(lc_N_5.time, lc_N_5.counts, lc_N_5.counts_err, window)
(lc_BLR_P_times_5, lc_BLR_P_counts_5, lc_BLR_P_err_5) = PyROA.RunningOptimalAverage(lc_BLR_N_5.time, lc_BLR_N_5.counts, lc_BLR_N_5.counts_err, window)
lcp_5 = Lightcurve(lc_P_times_5, lc_P_counts_5, err=lc_P_err_5)
lcBLRp_5 = Lightcurve(lc_BLR_P_times_5, lc_BLR_P_counts_5, err=lc_BLR_P_err_5)
avg_cs_BLR_P_5 = AveragedCrossspectrum.from_lightcurve(lcBLRp_5, lcp_5, cs_binning)
log_rb_cs_P_5 = avg_cs_BLR_P_5.rebin_log(f=1.2)

freq_lags_P_5, freq_lags_err_P_5 = log_rb_cs_P_5.time_lag()
# Out:
# /opt/conda/lib/python3.11/site-packages/stingray/utils.py:406: UserWarning: SIMON says: Bin sizes in input time array aren't equal throughout! This could cause problems with Fourier transforms. Please make the input time evenly sampled.Only use with LombScargleCrossspectrum, LombScarglePowerspectrum and QPO using GPResult
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# 3it [00:00, 1481.56it/s]
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1914: RuntimeWarning: invalid value encountered in sqrt
#   n_ph = np.sqrt(n_ph1 * n_ph2)
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1125: UserWarning: n_ave is below 30. Please note that the error bars on the quantities derived from the cross spectrum are only reliable for a large number of averaged powers.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1139: RuntimeWarning: invalid value encountered in sqrt
#   dRe = dIm = dG = np.sqrt(power_over_2n * (seg_power - frac))
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1141: RuntimeWarning: invalid value encountered in sqrt
#   dphi = np.sqrt(
# /opt/conda/lib/python3.11/site-packages/stingray/crossspectrum.py:2912: UserWarning: Some error bars in the Averaged Crossspectrum are invalid.Defaulting to sqrt(2 / M) in Leahy norm, rescaled to the appropriate norm.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/stingray/crossspectrum.py:2917: RuntimeWarning: invalid value encountered in sqrt
#   Nph = np.sqrt(cs.nphots1 * cs.nphots2)
# /opt/conda/lib/python3.11/site-packages/stingray/utils.py:406: UserWarning: SIMON says: Number of segments used in averaging is significantly low. The result might not follow the expected statistical distributions.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)

# %%
SN = 3.3
lc_BLR_N_30 = np.random.normal(lc_BLR_N, abs(lc_BLR_N/SN))
lc_N_30 = np.random.normal(lc_N, abs(lc_N/SN))
lc_BLR_N_30 = Lightcurve(lc_BLR.time, lc_BLR_N_30)
lc_N_30 = Lightcurve(lc.time, lc_N_30)
lc_N_30.counts_err = abs(lc_N_30.counts*error_in_flux)
lc_BLR_N_30.counts_err = abs(lc_BLR_N_30.counts*error_in_flux)
(lc_P_times_30, lc_P_counts_30, lc_P_err_30) = PyROA.RunningOptimalAverage(lc_N_30.time, lc_N_30.counts, lc_N_30.counts_err, window)
(lc_BLR_P_times_30, lc_BLR_P_counts_30, lc_BLR_P_err_30) = PyROA.RunningOptimalAverage(lc_BLR_N_30.time, lc_BLR_N_30.counts, lc_BLR_N_30.counts_err, window)
lcp_30 = Lightcurve(lc_P_times_30, lc_P_counts_30, err=lc_P_err_30)
lcBLRp_30 = Lightcurve(lc_BLR_P_times_30, lc_BLR_P_counts_30, err=lc_BLR_P_err_30)
avg_cs_BLR_P_30 = AveragedCrossspectrum.from_lightcurve(lcBLRp_30, lcp_30, cs_binning)
log_rb_cs_P_30 = avg_cs_BLR_P_30.rebin_log(f=1.2)

freq_lags_P_30, freq_lags_err_P_30 = log_rb_cs_P_30.time_lag()
# Out:
# /opt/conda/lib/python3.11/site-packages/stingray/utils.py:406: UserWarning: SIMON says: Bin sizes in input time array aren't equal throughout! This could cause problems with Fourier transforms. Please make the input time evenly sampled.Only use with LombScargleCrossspectrum, LombScarglePowerspectrum and QPO using GPResult
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)
# 3it [00:00, 1489.28it/s]
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1914: RuntimeWarning: invalid value encountered in sqrt
#   n_ph = np.sqrt(n_ph1 * n_ph2)
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1125: UserWarning: n_ave is below 30. Please note that the error bars on the quantities derived from the cross spectrum are only reliable for a large number of averaged powers.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1139: RuntimeWarning: invalid value encountered in sqrt
#   dRe = dIm = dG = np.sqrt(power_over_2n * (seg_power - frac))
# /opt/conda/lib/python3.11/site-packages/stingray/fourier.py:1141: RuntimeWarning: invalid value encountered in sqrt
#   dphi = np.sqrt(
# /opt/conda/lib/python3.11/site-packages/stingray/crossspectrum.py:2912: UserWarning: Some error bars in the Averaged Crossspectrum are invalid.Defaulting to sqrt(2 / M) in Leahy norm, rescaled to the appropriate norm.
#   warnings.warn(
# /opt/conda/lib/python3.11/site-packages/stingray/crossspectrum.py:2917: RuntimeWarning: invalid value encountered in sqrt
#   Nph = np.sqrt(cs.nphots1 * cs.nphots2)
# /opt/conda/lib/python3.11/site-packages/stingray/utils.py:406: UserWarning: SIMON says: Number of segments used in averaging is significantly low. The result might not follow the expected statistical distributions.
#   warnings.warn("SIMON says: {0}".format(message), **kwargs)

# %%
fig, ax = plt.subplots(1,1,figsize=(8,5))
ax.hlines(0, log_rb_cs.freq[0], log_rb_cs.freq[-1], color='black', linestyle='dashed', lw=2)
ax.errorbar(log_rb_cs_P_1.freq+0.05*log_rb_cs_P_1.freq, freq_lags_P_1, yerr=freq_lags_err_P_1,fmt="o", lw=1, color='blue', label='1% noise')
ax.errorbar(log_rb_cs_P_5.freq+0.05*log_rb_cs_P_5.freq, freq_lags_P_5, yerr=freq_lags_err_P_5,fmt="o", lw=1, color='green', label='5% noise')
ax.errorbar(log_rb_cs_P_10.freq+0.05*log_rb_cs_P_10.freq, freq_lags_P_10, yerr=freq_lags_err_P_10,fmt="o", lw=1, color='yellow', label='10% noise')
ax.errorbar(log_rb_cs_P_20.freq+0.05*log_rb_cs_P_20.freq, freq_lags_P_20, yerr=freq_lags_err_P_20,fmt="o", lw=1, color='orange', label='20% noise')
ax.errorbar(log_rb_cs_P_30.freq+0.05*log_rb_cs_P_30.freq, freq_lags_P_30, yerr=freq_lags_err_P_30,fmt="o", lw=1, color='red', label='30% noise')
ax.errorbar(log_rb_cs.freq, freq_lags, yerr=freq_lags_err, fmt="o", lw=1, color='purple', label='Original Light curve')
ax.set_xlabel("Frequency (Hz)")
ax.set_ylabel("Time lag (days)")
ax.set_title("Frequency-dependent Time Lags - Sampling Loss: {} SNR: {} Sampling Rate: {}".format(sampling_loss, SN, sampling_rate))
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)
ax.tick_params(which='major', width=1.5, length=7)
ax.tick_params(which='minor', width=1.5, length=4)
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(1.5)
plt.semilogx()
plt.legend()
# Include noise value in the filename
#filename = os.path.join('PYROA_test_FreqLag_dataloss(%)_{}_SN{}_samplingrate(per day){}.png'.format(sampling_loss, SN, sampling_rate))
#plt.savefig(filename,format = 'png', orientation = 'landscape', bbox_inches = 'tight')

plt.show()

# %% [markdown]
# ## Plot differences in frequency resolved lags for visualisation

# %%
diff_1 = []
diff_5 = []
diff_10 = []
diff_20 = []
diff_30 = []
zeros = []

for i in range(len(freq_lags_P_1)):
    diff_1.append(np.abs(freq_lags_P_1[i] - freq_lags[i])/ freq_lags_err[i]) 
    diff_5.append(np.abs(freq_lags_P_5[i] - freq_lags[i])/ freq_lags_err[i]) 
    diff_10.append(np.abs(freq_lags_P_10[i] - freq_lags[i])/ freq_lags_err[i]) 
    diff_20.append(np.abs(freq_lags_P_20[i] - freq_lags[i])/ freq_lags_err[i]) 
    diff_30.append(np.abs(freq_lags_P_30[i] - freq_lags[i])/ freq_lags_err[i]) 

for i in range(len(freq_lags)):
    zeros.append(0)

# %%
fig, ax = plt.subplots(1,1,figsize=(8,5))
ax.hlines(0, log_rb_cs.freq[0], log_rb_cs.freq[-1], color='black', linestyle='dashed', lw=2)
ax.scatter(log_rb_cs_P_1.freq, diff_1,  color='blue', label='1% noise')
ax.scatter(log_rb_cs_P_5.freq, diff_5,  color='green', label='5% noise')
ax.scatter(log_rb_cs_P_10.freq, diff_10,  color='yellow', label='10% noise')
ax.scatter(log_rb_cs_P_20.freq, diff_20,  color='orange', label='20% noise')
ax.scatter(log_rb_cs_P_30.freq, diff_30, color='red', label='30% noise')
ax.errorbar(log_rb_cs.freq, zeros, yerr=[zeros,freq_lags_err], fmt="o", lw=1, color='purple',label='Original Light curve with error bars',alpha = 0.4, )
ax.set_xlabel("Frequency (1/day)", fontsize=15)
ax.set_ylabel("days", fontsize=15)

ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)
ax.tick_params(which='major', width=1.5, length=7)
ax.tick_params(which='minor', width=1.5, length=4)
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_linewidth(1.5)
plt.semilogx()
plt.legend()
# Include noise value in the filename
#filename = os.path.join('PYROA_test_FreqLag_dataloss(%)_{}_SN{}_samplingrate(per day){}.png'.format(sampling_loss, SN, sampling_rate))
#plt.savefig(filename,format = 'png', orientation = 'landscape', bbox_inches = 'tight')
plt.subplots_adjust(top=1, bottom=0.15)
plt.savefig('/home/jovyan/AS4013/testingPYROAnoise.png')
plt.show()
